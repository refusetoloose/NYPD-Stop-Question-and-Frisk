# %%
#%%

#Import Statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#%%

# Load the data set
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 150)
df_raw= pd.read_csv('2012.csv')
df_raw.head()

# Get meaning and type of data
# Create a string to store data types for all columns
data_types_string = ""

# Concatenate column names and data types
for column in df_raw.columns:
    data_types_string += f"{column}: {df_raw[column].dtype}, "

# Print the string
print(data_types_string)
# Out:
# <ipython-input-2-a1b88869863e>:5: DtypeWarning: Columns (10,73,103,110,111) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw= pd.read_csv('2012.csv')
# year: int64, pct: int64, ser_num: int64, datestop: int64, timestop: int64, recstat: object, inout: object, trhsloc: object, perobs: float64, crimsusp: object, perstop: object, typeofid: object, explnstp: object, othpers: object, arstmade: object, arstoffn: object, sumissue: object, sumoffen: object, compyear: int64, comppct: int64, offunif: object, officrid: object, frisked: object, searched: object, contrabn: object, adtlrept: object, pistol: object, riflshot: object, asltweap: object, knifcuti: object, machgun: object, othrweap: object, pf_hands: object, pf_wall: object, pf_grnd: object, pf_drwep: object, pf_ptwep: object, pf_baton: object, pf_hcuff: object, pf_pepsp: object, pf_other: object, radio: object, ac_rept: object, ac_inves: object, rf_vcrim: object, rf_othsw: object, ac_proxm: object, rf_attir: object, cs_objcs: object, cs_descr: object, cs_casng: object, cs_lkout: object, rf_vcact: object, cs_cloth: object, cs_drgtr: object, ac_evasv: object, ac_assoc: object, cs_furtv: object, rf_rfcmp: object, ac_cgdir: object, rf_verbl: object, cs_vcrim: object, cs_bulge: object, cs_other: object, ac_incid: object, ac_time: object, rf_knowl: object, ac_stsnd: object, ac_other: object, sb_hdobj: object, sb_outln: object, sb_admis: object, sb_other: object, repcmd: object, revcmd: int64, rf_furt: object, rf_bulg: object, offverb: object, offshld: object, forceuse: object, sex: object, race: object, dob: int64, age: int64, ht_feet: int64, ht_inch: int64, weight: int64, haircolr: object, eyecolor: object, build: object, othfeatr: object, addrtyp: object, rescode: object, premtype: object, premname: object, addrnum: object, stname: object, stinter: object, crossst: object, aptnum: object, city: object, state: object, zip: object, addrpct: object, sector: object, beat: object, post: object, xcoord: object, ycoord: object, dettypcm: object, linecm: object, detailcm: object,

# %%
#%%

# Get meaning and type of data
df_raw.info()
df_raw.dtypes
df_raw.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532911 entries, 0 to 532910
# Columns: 112 entries, year to detailcm
# dtypes: float64(1), int64(13), object(98)
# memory usage: 455.4+ MB
#             year            pct        ser_num      datestop       timestop  \
# count   532911.0  532911.000000  532911.000000  5.329110e+05  532911.000000
# unique       NaN            NaN            NaN           NaN            NaN
# top          NaN            NaN            NaN           NaN            NaN
# freq         NaN            NaN            NaN           NaN            NaN
# mean      2012.0      66.502354    4979.569876  5.563631e+06    1415.161796
# std          0.0      32.343511    4360.019625  3.413338e+06     737.003276
# min       2012.0       1.000000       1.000000  1.012012e+06       0.000000
# 25%       2012.0      41.000000    1790.000000  2.292012e+06    1002.000000
# 50%       2012.0      70.000000    3790.000000  5.052012e+06    1615.000000
# 75%       2012.0      94.000000    6982.000000  8.252012e+06    2030.000000
# max       2012.0     123.000000   24652.000000  1.231201e+07    2359.000000
#
#        recstat   inout trhsloc         perobs crimsusp perstop typeofid  \
# count   532911  532911  532911  532911.000000   532909  532911   532911
# unique       2       2       3            NaN     6825     150        4
# top          1       O       P            NaN      FEL       5        P
# freq    269234  417377  413990            NaN   104935  177688   289131
# mean       NaN     NaN     NaN       2.445776      NaN     NaN      NaN
# std        NaN     NaN     NaN       5.028139      NaN     NaN      NaN
# min        NaN     NaN     NaN       0.000000      NaN     NaN      NaN
# 25%        NaN     NaN     NaN       1.000000      NaN     NaN      NaN
# 50%        NaN     NaN     NaN       1.000000      NaN     NaN      NaN
# 75%        NaN     NaN     NaN       2.000000      NaN     NaN      NaN
# max        NaN     NaN     NaN     955.000000      NaN     NaN      NaN
#
#        explnstp othpers arstmade arstoffn sumissue sumoffen  compyear  \
# count    532911  532911   532911   532909   532911   532902  532911.0
# unique        2       2        2     3754        2     4039       NaN
# top           Y       N        N                 N                NaN
# freq     532535  430923   500596   500600   505472   512037       NaN
# mean        NaN     NaN      NaN      NaN      NaN      NaN       0.0
# std         NaN     NaN      NaN      NaN      NaN      NaN       0.0
# min         NaN     NaN      NaN      NaN      NaN      NaN       0.0
# 25%         NaN     NaN      NaN      NaN      NaN      NaN       0.0
# 50%         NaN     NaN      NaN      NaN      NaN      NaN       0.0
# 75%         NaN     NaN      NaN      NaN      NaN      NaN       0.0
# max         NaN     NaN      NaN      NaN      NaN      NaN       0.0
#
#          comppct offunif officrid frisked searched contrabn adtlrept  pistol  \
# count   532911.0  532911   532911  532911   532911   532911   532911  532911
# unique       NaN       2        2       2        2        2        1       2
# top          NaN       Y                Y        N        N        N       N
# freq         NaN  401059   526511  297244   488663   523677   532911  532249
# mean         0.0     NaN      NaN     NaN      NaN      NaN      NaN     NaN
# std          0.0     NaN      NaN     NaN      NaN      NaN      NaN     NaN
# min          0.0     NaN      NaN     NaN      NaN      NaN      NaN     NaN
# 25%          0.0     NaN      NaN     NaN      NaN      NaN      NaN     NaN
# 50%          0.0     NaN      NaN     NaN      NaN      NaN      NaN     NaN
# 75%          0.0     NaN      NaN     NaN      NaN      NaN      NaN     NaN
# max          0.0     NaN      NaN     NaN      NaN      NaN      NaN     NaN
#
#        riflshot asltweap knifcuti machgun othrweap pf_hands pf_wall pf_grnd  \
# count    532911   532911   532911  532911   532911   532911  532911  532911
# unique        2        2        2       2        2        2       2       2
# top           N        N        N       N        N        N       N       N
# freq     532898   532860   528206  532908   531589   462623  520284  531089
# mean        NaN      NaN      NaN     NaN      NaN      NaN     NaN     NaN
# std         NaN      NaN      NaN     NaN      NaN      NaN     NaN     NaN
# min         NaN      NaN      NaN     NaN      NaN      NaN     NaN     NaN
# 25%         NaN      NaN      NaN     NaN      NaN      NaN     NaN     NaN
# 50%         NaN      NaN      NaN     NaN      NaN      NaN     NaN     NaN
# 75%         NaN      NaN      NaN     NaN      NaN      NaN     NaN     NaN
# max         NaN      NaN      NaN     NaN      NaN      NaN     NaN     NaN
#
#        pf_drwep pf_ptwep pf_baton pf_hcuff pf_pepsp pf_other   radio ac_rept  \
# count    532911   532911   532911   532911   532911   532911  532911  532911
# unique        2        2        2        2        2        2       2       2
# top           N        N        N        N        N        N       N       N
# freq     531611   531678   532854   513665   532854   529421  403875  465902
# mean        NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
# std         NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
# min         NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
# 25%         NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
# 50%         NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
# 75%         NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
# max         NaN      NaN      NaN      NaN      NaN      NaN     NaN     NaN
#
#        ac_inves rf_vcrim rf_othsw ac_proxm rf_attir cs_objcs cs_descr  \
# count    532911   532911   532911   532911   532911   532911   532911
# unique        2        2        2        2        2        2        2
# top           N        N        N        N        N        N        N
# freq     458488   463955   515019   412500   493450   519463   444997
# mean        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# std         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# min         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 25%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 50%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 75%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# max         NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        cs_casng cs_lkout rf_vcact cs_cloth cs_drgtr ac_evasv ac_assoc  \
# count    532911   532911   532911   532911   532911   532911   532911
# unique        2        2        2        2        2        2        2
# top           N        N        N        N        N        N        N
# freq     343055   432273   489273   507914   493933   431677   508725
# mean        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# std         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# min         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 25%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 50%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 75%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# max         NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        cs_furtv rf_rfcmp ac_cgdir rf_verbl cs_vcrim cs_bulge cs_other  \
# count    532911   532911   532911   532911   532911   532911   532911
# unique        2        2        2        2        2        2        2
# top           Y        N        N        N        N        N        N
# freq     274645   490633   405926   529549   474002   493989   449598
# mean        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# std         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# min         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 25%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 50%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 75%         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# max         NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        ac_incid ac_time rf_knowl ac_stsnd ac_other sb_hdobj sb_outln sb_admis  \
# count    532911  532911   532911   532911   532911   532911   532911   532911
# unique        2       2        2        2        2        2        2        2
# top           Y       N        N        N        N        N        N        N
# freq     319862  299354   522919   519278   514585   509706   530116   531450
# mean        NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# std         NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# min         NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 25%         NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 50%         NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 75%         NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# max         NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        sb_other    repcmd         revcmd rf_furt rf_bulg offverb offshld  \
# count    532911  532911.0  532911.000000  532911  532911  532911  532911
# unique        2     463.0            NaN       2       2       2       2
# top           N     165.0            NaN       N       N
# freq     513967   34602.0            NaN  323411  495579  430032  402902
# mean        NaN       NaN     237.833685     NaN     NaN     NaN     NaN
# std         NaN       NaN     292.130066     NaN     NaN     NaN     NaN
# min         NaN       NaN       1.000000     NaN     NaN     NaN     NaN
# 25%         NaN       NaN      67.000000     NaN     NaN     NaN     NaN
# 50%         NaN       NaN     107.000000     NaN     NaN     NaN     NaN
# 75%         NaN       NaN     165.000000     NaN     NaN     NaN     NaN
# max         NaN       NaN     879.000000     NaN     NaN     NaN     NaN
#
#        forceuse     sex    race           dob            age        ht_feet  \
# count    532911  532911  532911  5.329110e+05  532911.000000  532911.000000
# unique        7       3       8           NaN            NaN            NaN
# top                   M       B           NaN            NaN            NaN
# freq     465609  487065  284229           NaN            NaN            NaN
# mean        NaN     NaN     NaN  8.947660e+06      28.769539       5.181846
# std         NaN     NaN     NaN  3.839557e+06      24.006996       0.397057
# min         NaN     NaN     NaN  1.011001e+06       0.000000       3.000000
# 25%         NaN     NaN     NaN  6.051983e+06      19.000000       5.000000
# 50%         NaN     NaN     NaN  1.031200e+07      24.000000       5.000000
# 75%         NaN     NaN     NaN  1.231190e+07      34.000000       5.000000
# max         NaN     NaN     NaN  1.231201e+07     999.000000       7.000000
#
#               ht_inch         weight haircolr eyecolor   build othfeatr  \
# count   532911.000000  532911.000000   532911   532911  532911   532911
# unique            NaN            NaN       11       13       5        9
# top               NaN            NaN       BK       BR       M
# freq              NaN            NaN   404114   479038  308601   532896
# mean         6.417967     169.284830      NaN      NaN     NaN      NaN
# std          3.363582      36.838004      NaN      NaN     NaN      NaN
# min          0.000000       0.000000      NaN      NaN     NaN      NaN
# 25%          4.000000     150.000000      NaN      NaN     NaN      NaN
# 50%          7.000000     165.000000      NaN      NaN     NaN      NaN
# 75%          9.000000     180.000000      NaN      NaN     NaN      NaN
# max         11.000000     999.000000      NaN      NaN     NaN      NaN
#
#        addrtyp rescode premtype premname addrnum  stname   stinter   crossst  \
# count   532911  532911   532911   532818  532911  532911    532911    532911
# unique       1       1        1    13716   11206    4803      6858      6732
# top          R                    STREET                  BROADWAY  BROADWAY
# freq    532911  532911   532911   200106  312070  306954     11975      5110
# mean       NaN     NaN      NaN      NaN     NaN     NaN       NaN       NaN
# std        NaN     NaN      NaN      NaN     NaN     NaN       NaN       NaN
# min        NaN     NaN      NaN      NaN     NaN     NaN       NaN       NaN
# 25%        NaN     NaN      NaN      NaN     NaN     NaN       NaN       NaN
# 50%        NaN     NaN      NaN      NaN     NaN     NaN       NaN       NaN
# 75%        NaN     NaN      NaN      NaN     NaN     NaN       NaN       NaN
# max        NaN     NaN      NaN      NaN     NaN     NaN       NaN       NaN
#
#         aptnum      city   state     zip   addrpct  sector    beat    post  \
# count   532911    532911  532911  532911  532911.0  532911  532911  532911
# unique       1         6       1       1     152.0      20      11     100
# top             BROOKLYN                      75.0       A
# freq    532911    188707  532911  532911   20506.0   55505  337499  477757
# mean       NaN       NaN     NaN     NaN       NaN     NaN     NaN     NaN
# std        NaN       NaN     NaN     NaN       NaN     NaN     NaN     NaN
# min        NaN       NaN     NaN     NaN       NaN     NaN     NaN     NaN
# 25%        NaN       NaN     NaN     NaN       NaN     NaN     NaN     NaN
# 50%        NaN       NaN     NaN     NaN       NaN     NaN     NaN     NaN
# 75%        NaN       NaN     NaN     NaN       NaN     NaN     NaN     NaN
# max        NaN       NaN     NaN     NaN       NaN     NaN     NaN     NaN
#
#         xcoord  ycoord dettypcm    linecm  detailcm
# count   532911  532911   532911  532911.0  532911.0
# unique   51225   59245        2       4.0     149.0
# top                          CM       1.0      20.0
# freq     15585   15585   532909  418838.0  127383.0
# mean       NaN     NaN      NaN       NaN       NaN
# std        NaN     NaN      NaN       NaN       NaN
# min        NaN     NaN      NaN       NaN       NaN
# 25%        NaN     NaN      NaN       NaN       NaN
# 50%        NaN     NaN      NaN       NaN       NaN
# 75%        NaN     NaN      NaN       NaN       NaN
# max        NaN     NaN      NaN       NaN       NaN

# %%
# %% Verify data quality

# Are there Duplicate data?
df_raw[df_raw.duplicated()].shape
# Out:
# (0, 112)

# %%
# %%

# Are there missing values?
df_raw.isnull().sum()
# Out:
# year         0
# pct          0
# ser_num      0
# datestop     0
# timestop     0
# recstat      0
# inout        0
# trhsloc      0
# perobs       0
# crimsusp     2
# perstop      0
# typeofid     0
# explnstp     0
# othpers      0
# arstmade     0
# arstoffn     2
# sumissue     0
# sumoffen     9
# compyear     0
# comppct      0
# offunif      0
# officrid     0
# frisked      0
# searched     0
# contrabn     0
# adtlrept     0
# pistol       0
# riflshot     0
# asltweap     0
# knifcuti     0
# machgun      0
# othrweap     0
# pf_hands     0
# pf_wall      0
# pf_grnd      0
# pf_drwep     0
# pf_ptwep     0
# pf_baton     0
# pf_hcuff     0
# pf_pepsp     0
# pf_other     0
# radio        0
# ac_rept      0
# ac_inves     0
# rf_vcrim     0
# rf_othsw     0
# ac_proxm     0
# rf_attir     0
# cs_objcs     0
# cs_descr     0
# cs_casng     0
# cs_lkout     0
# rf_vcact     0
# cs_cloth     0
# cs_drgtr     0
# ac_evasv     0
# ac_assoc     0
# cs_furtv     0
# rf_rfcmp     0
# ac_cgdir     0
# rf_verbl     0
# cs_vcrim     0
# cs_bulge     0
# cs_other     0
# ac_incid     0
# ac_time      0
# rf_knowl     0
# ac_stsnd     0
# ac_other     0
# sb_hdobj     0
# sb_outln     0
# sb_admis     0
# sb_other     0
# repcmd       0
# revcmd       0
# rf_furt      0
# rf_bulg      0
# offverb      0
# offshld      0
# forceuse     0
# sex          0
# race         0
# dob          0
# age          0
# ht_feet      0
# ht_inch      0
# weight       0
# haircolr     0
# eyecolor     0
# build        0
# othfeatr     0
# addrtyp      0
# rescode      0
# premtype     0
# premname    93
# addrnum      0
# stname       0
# stinter      0
# crossst      0
# aptnum       0
# city         0
# state        0
# zip          0
# addrpct      0
# sector       0
# beat         0
# post         0
# xcoord       0
# ycoord       0
# dettypcm     0
# linecm       0
# detailcm     0
# dtype: int64

# %%
# %% How do you deal with these problems?

#Remove all the rows with null value and generate stats again
df_clean = df_raw.dropna()
df_clean.shape
# Out:
# (532805, 112)

# %%
#%% Check How Many rows were removed

print(len(df_raw) - len(df_clean))
# Out:
# 106

# %%
#%% Generate Stats again

df_clean.isnull().sum()
# Out:
# year        0
# pct         0
# ser_num     0
# datestop    0
# timestop    0
# recstat     0
# inout       0
# trhsloc     0
# perobs      0
# crimsusp    0
# perstop     0
# typeofid    0
# explnstp    0
# othpers     0
# arstmade    0
# arstoffn    0
# sumissue    0
# sumoffen    0
# compyear    0
# comppct     0
# offunif     0
# officrid    0
# frisked     0
# searched    0
# contrabn    0
# adtlrept    0
# pistol      0
# riflshot    0
# asltweap    0
# knifcuti    0
# machgun     0
# othrweap    0
# pf_hands    0
# pf_wall     0
# pf_grnd     0
# pf_drwep    0
# pf_ptwep    0
# pf_baton    0
# pf_hcuff    0
# pf_pepsp    0
# pf_other    0
# radio       0
# ac_rept     0
# ac_inves    0
# rf_vcrim    0
# rf_othsw    0
# ac_proxm    0
# rf_attir    0
# cs_objcs    0
# cs_descr    0
# cs_casng    0
# cs_lkout    0
# rf_vcact    0
# cs_cloth    0
# cs_drgtr    0
# ac_evasv    0
# ac_assoc    0
# cs_furtv    0
# rf_rfcmp    0
# ac_cgdir    0
# rf_verbl    0
# cs_vcrim    0
# cs_bulge    0
# cs_other    0
# ac_incid    0
# ac_time     0
# rf_knowl    0
# ac_stsnd    0
# ac_other    0
# sb_hdobj    0
# sb_outln    0
# sb_admis    0
# sb_other    0
# repcmd      0
# revcmd      0
# rf_furt     0
# rf_bulg     0
# offverb     0
# offshld     0
# forceuse    0
# sex         0
# race        0
# dob         0
# age         0
# ht_feet     0
# ht_inch     0
# weight      0
# haircolr    0
# eyecolor    0
# build       0
# othfeatr    0
# addrtyp     0
# rescode     0
# premtype    0
# premname    0
# addrnum     0
# stname      0
# stinter     0
# crossst     0
# aptnum      0
# city        0
# state       0
# zip         0
# addrpct     0
# sector      0
# beat        0
# post        0
# xcoord      0
# ycoord      0
# dettypcm    0
# linecm      0
# detailcm    0
# dtype: int64

# %%
#%%

# Describe categorical columns
categorical_columns = df_clean.select_dtypes(include=['object'])
categorical_description = categorical_columns.describe(include='all')
print("Categorical Columns Description:\n", categorical_description)
categorical_columns.columns.shape
# Out:
# Categorical Columns Description:
#         recstat   inout trhsloc crimsusp perstop typeofid explnstp othpers  \
# count   532805  532805  532805   532805  532805   532805   532805  532805
# unique       2       2       3     6825     150        4        2       2
# top          1       O       P      FEL       5        P        Y       N
# freq    269155  417306  413924   104919  177641   289067   532429  430845
#
#        arstmade arstoffn sumissue sumoffen offunif officrid frisked searched  \
# count    532805   532805   532805   532805  532805   532805  532805   532805
# unique        2     3754        2     4038       2        2       2        2
# top           N                 N                Y                Y        N
# freq     500496   500500   505377   511941  400993   526407  297191   488570
#
#        contrabn adtlrept  pistol riflshot asltweap knifcuti machgun othrweap  \
# count    532805   532805  532805   532805   532805   532805  532805   532805
# unique        2        1       2        2        2        2       2        2
# top           N        N       N        N        N        N       N        N
# freq     523576   532805  532143   532792   532754   528100  532802   531483
#
#        pf_hands pf_wall pf_grnd pf_drwep pf_ptwep pf_baton pf_hcuff pf_pepsp  \
# count    532805  532805  532805   532805   532805   532805   532805   532805
# unique        2       2       2        2        2        2        2        2
# top           N       N       N        N        N        N        N        N
# freq     462532  520181  530983   531505   531572   532748   513563   532748
#
#        pf_other   radio ac_rept ac_inves rf_vcrim rf_othsw ac_proxm rf_attir  \
# count    532805  532805  532805   532805   532805   532805   532805   532805
# unique        2       2       2        2        2        2        2        2
# top           N       N       N        N        N        N        N        N
# freq     529315  403793  465804   458393   463853   514922   412416   493349
#
#        cs_objcs cs_descr cs_casng cs_lkout rf_vcact cs_cloth cs_drgtr  \
# count    532805   532805   532805   532805   532805   532805   532805
# unique        2        2        2        2        2        2        2
# top           N        N        N        N        N        N        N
# freq     519358   444908   342997   432185   489174   507810   493829
#
#        ac_evasv ac_assoc cs_furtv rf_rfcmp ac_cgdir rf_verbl cs_vcrim  \
# count    532805   532805   532805   532805   532805   532805   532805
# unique        2        2        2        2        2        2        2
# top           N        N        Y        N        N        N        N
# freq     431587   508623   274600   490530   405844   529443   473904
#
#        cs_bulge cs_other ac_incid ac_time rf_knowl ac_stsnd ac_other sb_hdobj  \
# count    532805   532805   532805  532805   532805   532805   532805   532805
# unique        2        2        2       2        2        2        2        2
# top           N        N        Y       N        N        N        N        N
# freq     493892   449517   319792  299294   522815   519173   514489   509608
#
#        sb_outln sb_admis sb_other  repcmd rf_furt rf_bulg offverb offshld  \
# count    532805   532805   532805  532805  532805  532805  532805  532805
# unique        2        2        2     463       2       2       2       2
# top           N        N        N     165       N       N
# freq     530011   531344   513866   34600  323341  495479  429958  402836
#
#        forceuse     sex    race haircolr eyecolor   build othfeatr addrtyp  \
# count    532805  532805  532805   532805   532805  532805   532805  532805
# unique        7       3       8       11       13       5        9       1
# top                   M       B       BK       BR       M                R
# freq     465517  486974  284168   404038   478947  308540   532790  532805
#
#        rescode premtype premname addrnum  stname   stinter   crossst  aptnum  \
# count   532805   532805   532805  532805  532805    532805    532805  532805
# unique       1        1    13716   11206    4802      6857      6731       1
# top                       STREET                  BROADWAY  BROADWAY
# freq    532805   532805   200099  312010  306894     11975      5110  532805
#
#             city   state     zip  addrpct  sector    beat    post  xcoord  \
# count     532805  532805  532805   532805  532805  532805  532805  532805
# unique         6       1       1      152      20      11     100   51222
# top     BROOKLYN                       75       A
# freq      188653  532805  532805    20505   55483  337446  477660   15581
#
#         ycoord dettypcm  linecm  detailcm
# count   532805   532805  532805    532805
# unique   59242        2       4       149
# top                  CM       1        20
# freq     15581   532803  418753    127358
# (98,)

# %%
#%%

# Describe numerical columns
numerical_columns = df_clean.select_dtypes(exclude=['object'])
numerical_description = numerical_columns.describe(include='all')
print("Numerical Columns Description:\n", numerical_description)
numerical_description.columns.shape
# Out:
# Numerical Columns Description:
#             year            pct        ser_num      datestop       timestop  \
# count  532805.0  532805.000000  532805.000000  5.328050e+05  532805.000000
# mean     2012.0      66.505354    4979.832524  5.563744e+06    1415.193649
# std         0.0      32.343740    4360.164515  3.413403e+06     736.994783
# min      2012.0       1.000000       1.000000  1.012012e+06       0.000000
# 25%      2012.0      41.000000    1790.000000  2.292012e+06    1002.000000
# 50%      2012.0      70.000000    3790.000000  5.052012e+06    1615.000000
# 75%      2012.0      94.000000    6982.000000  8.252012e+06    2030.000000
# max      2012.0     123.000000   24652.000000  1.231201e+07    2359.000000
#
#               perobs  compyear   comppct         revcmd           dob  \
# count  532805.000000  532805.0  532805.0  532805.000000  5.328050e+05
# mean        2.445737       0.0       0.0     237.819401  8.947672e+06
# std         5.028396       0.0       0.0     292.114948  3.839569e+06
# min         0.000000       0.0       0.0       1.000000  1.011001e+06
# 25%         1.000000       0.0       0.0      67.000000  6.051983e+06
# 50%         1.000000       0.0       0.0     107.000000  1.031200e+07
# 75%         2.000000       0.0       0.0     165.000000  1.231190e+07
# max       955.000000       0.0       0.0     879.000000  1.231201e+07
#
#                  age        ht_feet        ht_inch         weight
# count  532805.000000  532805.000000  532805.000000  532805.000000
# mean       28.769045       5.181853       6.417939     169.285166
# std        24.008767       0.397064       3.363586      36.838862
# min         0.000000       3.000000       0.000000       0.000000
# 25%        19.000000       5.000000       4.000000     150.000000
# 50%        24.000000       5.000000       7.000000     165.000000
# 75%        34.000000       5.000000       9.000000     180.000000
# max       999.000000       7.000000      11.000000     999.000000
# (14,)

# %%
#%% Are there any Outliers?

# Lets Find out using Zscores 
from scipy.stats import zscore
# Calculate Z-scores for numerical columns
z_scores = df_clean.select_dtypes(include='number').apply(zscore)
# Identify outliers based on a threshold (e.g., 3 or -3)
outliers = (z_scores > 3) | (z_scores < -3)
# Count the number of outliers in each numerical column
num_outliers = outliers.sum()
# Print the number of outliers for each numerical column
print("Number of outliers in each numerical column:")
print(num_outliers)
#Yes based on Zscores, ser_num and perobs age and ht_feet and weight seems to be outliers
#Lets ignore ser_num as it doesnt add much value
# Out:
# Number of outliers in each numerical column:
# year            0
# pct             0
# ser_num     11232
# datestop        0
# timestop        0
# perobs       4959
# compyear        0
# comppct         0
# revcmd          0
# dob             0
# age           902
# ht_feet       270
# ht_inch         0
# weight       4453
# dtype: int64

# %%
#%% Visualize distribution of identified outliers

# Columns with outliers identified using z-score
outlier_columns_zscore = ['perobs', 'age', 'ht_feet', 'weight']

# Create box plots for each column
for column in outlier_columns_zscore:
    plt.figure(figsize=(8, 6))
    plt.boxplot(df_clean[column], vert=False)
    plt.title(f'Box plot of {column} with outliers (z-score method)')
    plt.xlabel(column)
    plt.show()

# %%
#%%

df_clean['age'].unique()
# Out:
# array([ 20,  18,  19,  37,  21,  62,  31,  34,  26,  23,  54,  27,  17,
#         58,  24,  38,  68,  29,  16,  35,  15,  28,  13,  45,  22,  30,
#         43,  46,  36,  42,  41,  39,  14,  55,  25,  51,  48,  47,  52,
#         53,  32,  40,  60,  57,  50,  61,  63,  56,  99,  33,  49,  59,
#         12,  44,   1,  74, 124, 196, 999,  71,   2,  67,  66,  65,  64,
#        118,  77,  10,   0,  73,  80,  78,  70, 200, 205, 231, 447,  72,
#         11, 185, 170,  82,  75,   5,  76,  96, 169, 442,  69, 190, 125,
#        145, 312, 226, 520,   3,  81, 120, 385, 160,  86, 165, 305, 256,
#        296, 202, 180, 241, 127, 140, 255, 175, 130,  84, 220, 210, 321,
#         83, 123, 478, 555, 131, 119, 174, 195, 326,   9, 240, 150, 365,
#          8, 191, 674, 164, 189, 181, 233,  79, 178, 166, 461, 198, 161,
#          4,   6, 522,  91, 250, 223, 100,   7, 224, 335, 188, 510, 199,
#        246, 228,  89, 300, 216, 221, 511, 585, 287, 235, 410, 490, 338,
#        345, 278, 622, 463, 274, 212, 301, 265, 117, 422, 215, 214, 396,
#        343,  95, 129, 230, 206, 168,  85, 236, 114, 433, 310, 135, 421,
#        245, 694, 156, 515, 227, 177,  97, 115, 315, 691, 155, 401, 521,
#        452, 144, 346, 487, 319, 553, 270,  88, 333, 405, 306, 505, 218,
#        488, 225, 146, 222, 387, 247, 217, 171, 154, 211, 232, 244, 176,
#        437, 298, 361, 251, 451, 116, 187, 501, 201, 108, 469, 375, 121,
#        523, 110, 229, 263, 425, 556, 347, 411, 700, 258, 243, 309, 565,
#        261, 323,  87, 128, 219, 412, 363, 851, 512, 366, 360, 183, 352,
#        269,  98, 435, 354, 285, 113, 479, 242, 496, 260, 136, 334, 332,
#        455, 699, 254, 209, 253], dtype=int64)

# %%
#%%

len(df_clean[(df_clean['age'] >= 5) & (df_clean['age'] <= 100)]), len(df_clean[(df_clean['age'] < 5) | (df_clean['age'] > 100)])
# Out:
# (531028, 1777)

# %%
#%%Lets filter out age 

mode_age = df_clean['age'].mode()[0]
df_clean.loc[(df_clean['age'] < 5) | (df_clean['age'] > 100), 'age'] = mode_age

# %%
#%%

df_clean['age'].unique()
# Out:
# array([ 20,  18,  19,  37,  21,  62,  31,  34,  26,  23,  54,  27,  17,
#         58,  24,  38,  68,  29,  16,  35,  15,  28,  13,  45,  22,  30,
#         43,  46,  36,  42,  41,  39,  14,  55,  25,  51,  48,  47,  52,
#         53,  32,  40,  60,  57,  50,  61,  63,  56,  99,  33,  49,  59,
#         12,  44,  74,  71,  67,  66,  65,  64,  77,  10,  73,  80,  78,
#         70,  72,  11,  82,  75,   5,  76,  96,  69,  81,  86,  84,  83,
#          9,   8,  79,   6,  91, 100,   7,  89,  95,  85,  97,  88,  87,
#         98], dtype=int64)

# %%
#%%

df_clean['weight'].unique()
# Out:
# array([155, 175, 180, 210, 170, 140, 160, 135, 150, 190, 200, 120, 130,
#        145, 165, 185, 250, 220, 195, 125, 168, 110, 230, 115, 100, 240,
#        205, 215, 124, 157, 225, 173, 164, 280, 235, 275, 290, 199, 300,
#        198, 127, 178, 184, 176, 158, 260, 161, 320, 121, 299, 105,   8,
#         18, 147,  90, 116, 133, 163, 148, 153, 209, 138, 119, 270, 169,
#        188, 156, 187, 136,  75, 255, 162, 142, 179, 219, 212, 265, 126,
#        186, 183, 128,   4, 223, 181, 245, 154, 305, 197,  85, 172, 182,
#        514, 228, 285,  10, 171,  95, 208, 134, 152,  60, 149, 132,  25,
#        999, 146, 167, 246, 159, 214, 295, 450,  17, 166, 207, 204, 350,
#        315, 202, 213, 203, 118, 330, 226, 131, 112, 193,  29, 310, 192,
#        216, 206,  20, 144, 238, 189, 340, 196,   1, 174,  23, 400,  38,
#         62, 141, 143, 211, 485, 221, 256, 151, 122, 108, 375,  13, 425,
#        107, 111, 113,  19, 229, 101, 177,   2, 129, 191, 365, 237,  57,
#        137, 360, 370, 325, 222, 217, 201,  16, 257, 301,  15, 123, 242,
#        139, 262, 395, 247,  80,  70, 276,  93, 234,  99,  14,   5,  11,
#        103, 106, 114,  22, 236,  98, 117,  37, 355, 518, 233, 314, 218,
#          6,  34,  59,   7, 287, 104, 194,  36, 281,  44, 345,  55,  50,
#          0,  97, 109,  40, 232,  58, 227, 224, 500, 282, 102, 480,  41,
#         30, 510, 519,  65,  46, 288, 385,  28,  21, 332, 258, 380,   9,
#         56, 470,  52, 273,  27, 249, 277, 272, 289, 264,  32, 511,  92,
#         96, 267, 259, 261, 750, 296,  31, 442, 530, 252, 269, 248, 274,
#        278,  91,  24, 614, 515, 241, 418, 423,  26,   3, 239, 308, 339,
#        319,  84, 336, 291,  87,  12, 279, 440, 460,  35, 266, 390, 244,
#        329,  42, 254, 304, 368,  49, 286, 335, 445,  48, 253,  61, 268,
#        271, 371, 231, 302,  86, 349,  63, 251, 337,  89,  33, 600,  53,
#        540, 312, 436, 499, 283, 410, 916, 465,  43,  88, 918, 297, 810,
#         68,  83, 700, 612, 303, 429, 399, 415, 417, 525, 243, 475, 459,
#         45, 374, 353, 298, 405,  67, 311, 263,  54, 430,  47, 870, 321,
#        284,  94, 552, 316,  39, 318, 307], dtype=int64)

# %%
#%%

len(df_clean[(df_clean['weight'] <= 500) & (df_clean['weight'] >= 20)]), len(df_clean[(df_clean['weight'] > 500) | (df_clean['weight'] < 20)])
# Out:
# (531790, 1015)

# %%
#%%

mode_weight = df_clean['weight'].mode()[0]
df_clean.loc[(df_clean['weight'] > 500) | (df_clean['weight'] < 20), 'weight'] = mode_weight

# %%
#%% Lets Keep the Height in one column

# Lets convert the height in feet to inches and keep the height value of inches in one column
df_clean['height'] = df_clean['ht_feet'] * 12 + (df_clean['ht_inch'])

# Drop ht_feet and ht_inch columns
df_clean.drop(columns=['ht_feet', 'ht_inch'], inplace=True)
# Out:
# <ipython-input-20-622c6e90187c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['height'] = df_clean['ht_feet'] * 12 + (df_clean['ht_inch'])
# <ipython-input-20-622c6e90187c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop(columns=['ht_feet', 'ht_inch'], inplace=True)

# %%
#%% Lets handle the perobs

df_clean['perobs'].dtype
# Out:
# dtype('float64')

# %%
#%%

# Replace '**' with the mode of 'perobs'
mode_perobs = df_clean['perobs'].mode()[0]
df_clean['perobs'] = df_clean['perobs'].apply(lambda x: mode_perobs if x == '**' else x)

# Convert 'perobs' to numeric
df_clean['perobs'] = pd.to_numeric(df_clean['perobs'], errors='coerce').fillna(60)

# Convert 'perobs' to integer
df_clean['perobs'] = df_clean['perobs'].astype(int)

# Limit 'perobs' to a maximum of 60 minutes
df_clean['perobs'] = df_clean['perobs'].apply(lambda x: min(x, 60))
# Out:
# <ipython-input-22-12b07079aa5e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['perobs'] = df_clean['perobs'].apply(lambda x: mode_perobs if x == '**' else x)
# <ipython-input-22-12b07079aa5e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['perobs'] = pd.to_numeric(df_clean['perobs'], errors='coerce').fillna(60)
# <ipython-input-22-12b07079aa5e>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['perobs'] = df_clean['perobs'].astype(int)
# <ipython-input-22-12b07079aa5e>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['perobs'] = df_clean['perobs'].apply(lambda x: min(x, 60))

# %%
#%% Visualization for Distribution of Age

plt.figure(figsize=(10, 6))
plt.hist(df_clean['age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Ages')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#%% Visualization for Distibution of Weight

plt.figure(figsize=(10, 6))
plt.hist(df_clean['weight'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Weight')
plt.xlabel('Weight')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#%% Visualize Length of observation before Engaging

plt.figure(figsize=(10, 6))
plt.hist(df_clean['perobs'], bins=20, color='skyblue', edgecolor='black')
plt.title('Length of Observation Before Engaging')
plt.xlabel('Perobs')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#%% Lets categorize age and plot to see which age group were more likey suspected

labels = ['child', 'teen', 'young_adult', 'adult', 'middle_aged', 'older', 'senior']
points = [0, 12, 18, 25, 35, 55, 70, 100]
df_clean.loc[:, 'age_category'] = pd.cut(df_clean['age'], bins=points, labels=labels, right=False)
# Out:
# <ipython-input-26-c50a3fb0e3f9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.loc[:, 'age_category'] = pd.cut(df_clean['age'], bins=points, labels=labels, right=False)

# %%
# %%

plt.figure(figsize=(10, 6))
df_clean['age_category'].value_counts().plot(kind='bar')
plt.title('Distribution of Age Categories')
plt.xlabel('Age Category')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#%%

df_clean[['age','height','weight','perobs']].describe().transpose()
# Out:
#            count        mean        std   min    25%    50%    75%    max
# age     532805.0   28.150220  11.890153   5.0   19.0   24.0   34.0  100.0
# height  532805.0   68.600171   3.184677  36.0   67.0   69.0   71.0   95.0
# weight  532805.0  168.870816  29.159119  20.0  150.0  165.0  180.0  500.0
# perobs  532805.0    2.413459   3.536730   0.0    1.0    1.0    2.0   60.0

# %%
#%%

## Lets do data cleaning and handle unknown values
df_clean.forceuse.value_counts()
# Out:
# forceuse
#       465517
# DS     30723
# OT     14418
# SF     13941
# SW      5071
# OR      2119
# DO      1016
# Name: count, dtype: int64

# %%
#%% Remove replace blank with other in the 'forceuse' column

df_clean['forceuse'].unique()
df_clean['forceuse'].replace('', 'OT', inplace=True)
force_use_mapping = {
    'DS': 'DEFENSE OF SELF',
    'DO': 'DEFENSE OF OTHER',
    'OR': 'OVERCOME RESISTANCE',
    'OT': 'OTHER',
    'SF': 'SUSPECTED FLIGHT',
    'SW': 'SUSPECTED WEAPON'
}
df_clean['forceuse'] = df_clean['forceuse'].map(force_use_mapping)
# Out:
# <ipython-input-30-b5a10b4ca274>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['forceuse'].replace('', 'OT', inplace=True)
# <ipython-input-30-b5a10b4ca274>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['forceuse'] = df_clean['forceuse'].map(force_use_mapping)

# %%
#%% Lets not remove sex as many doesnt identify themself in both

df_clean.sex.value_counts()
# df_clean['sex'].unique()
# df_clean = df_clean[~df_clean['sex'].isin(['Z'])]
sex_mapping = {'M': 'Male', 'F': 'Female'}
df_clean['sex'] = df_clean['sex'].map(sex_mapping).fillna('Other')
# Out:
# <ipython-input-31-e40bd41cdde8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['sex'] = df_clean['sex'].map(sex_mapping).fillna('Other')

# %%
#%% Lets Merge 'U' Unknown and 'Z' Other into a single category 'Z' Other

df_clean['race'].unique()
df_clean['race'].replace(['Z', 'U'], 'Z', inplace=True)
race_mapping = {
    'B': 'BLACK',
    'Q': 'WHITE-HISPANIC',
    'W': 'WHITE',
    'P': 'BLACK-HISPANIC',
    'A': 'ASIAN/PACIFIC ISLANDER',
    'Z': 'OTHER',
    'U': 'UNKNOWN',
    'I': 'AMERICAN INDIAN/ALASKAN NATIVE'
}
df_clean['race'] = df_clean['race'].map(race_mapping).fillna(np.nan)
# Out:
# <ipython-input-32-171dd212225c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['race'].replace(['Z', 'U'], 'Z', inplace=True)
# <ipython-input-32-171dd212225c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['race'] = df_clean['race'].map(race_mapping).fillna(np.nan)

# %%
#%%

df_clean['haircolr'].unique()
df_clean['haircolr'].replace('XX', 'ZZ', inplace=True)
hair_color_mapping = {
    'BA': 'BALD',
    'BK': 'BLACK',
    'BL': 'BLOND',
    'BR': 'BROWN',
    'DY': 'DYED',
    'FR': 'FROSTED',
    'GY': 'GRAY',
    'RA': 'RED',
    'SN': 'SANDY',
    'SP': 'SALT AND PEPPER',
    'WH': 'WHITE',
    'XX': 'UNKNOWN',
    'ZZ': 'OTHER'
}
df_clean['haircolr'] = df_clean['haircolr'].map(hair_color_mapping)
# Out:
# <ipython-input-33-93785b3f8e80>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['haircolr'].replace('XX', 'ZZ', inplace=True)
# <ipython-input-33-93785b3f8e80>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['haircolr'] = df_clean['haircolr'].map(hair_color_mapping)
# <ipython-input-33-93785b3f8e80>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['haircolr'] = df_clean['haircolr'].map(hair_color_mapping)

# %%
#%%

df_clean['eyecolor'].unique()
df_clean['eyecolor'].replace(['XX', 'MC'], 'Z', inplace=True)
eye_color_mapping = {
    'BK': 'BLACK',
    'BL': 'BLUE',
    'BR': 'BROWN',
    'DF': 'TWO DIFFERENT',
    'GR': 'GREEN',
    'GY': 'GRAY',
    'HA': 'HAZEL',
    'MA': 'MAROON',
    'P': 'PINK',
    'VI': 'VIOLET',
    'XX': 'UNKNOWN',
    'Z': 'OTHER'
}
df_clean['eyecolor'] = df_clean['eyecolor'].map(eye_color_mapping)
# Out:
# <ipython-input-34-97a8e06b2290>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['eyecolor'].replace(['XX', 'MC'], 'Z', inplace=True)
# <ipython-input-34-97a8e06b2290>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['eyecolor'] = df_clean['eyecolor'].map(eye_color_mapping)

# %%
#%%

df_clean['build'].unique()
df_clean = df_clean[~df_clean['build'].isin(['Z'])]
build_mapping = {
    'H': 'HEAVY',
    'M': 'MEDIUM',
    'T': 'THIN',
    'U': 'MUSCULAR',
    'Z': 'UNKNOWN'
}
df_clean['build'] = df_clean['build'].map(build_mapping)

# %%
#%%

#Visualize distribution of race and city
plt.subplot(121)
df_clean.groupby('race').size().plot.pie(colormap='coolwarm')
plt.title('Distribution of Stopped Individuals by Race')
plt.subplot(122)
df_clean.groupby('city').size().plot.pie(colormap='viridis')
plt.title('Distribution of Stops by City')
plt.subplots_adjust(left=0.0, bottom=0.0, right=2, top=1.1, wspace=0.01, hspace=0.2)
plt.show()

# %%
#%% Visualize frisks by race

sns.catplot(x='race', hue='frisked', data=df_clean, kind='count', palette='coolwarm', edgecolor='0.6')
plt.title('Frisks by Race')
plt.grid()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2, top=0.8, wspace=0.01, hspace=0.2)

# %%
# %%

# Visualize distribution of frisks or no frisks by time of day
df_clean.pivot(columns='frisked')['timestop'].plot(kind='hist', stacked=True, bins=30, alpha=0.9, edgecolor='black')
plt.xticks(np.arange(0, 2500, step=600))
plt.xlim([0, 2400])
plt.xlabel('Time of Stop [HH:MM]')
plt.title('Distribution of Frisks by Time of Day')
plt.legend(['Not Frisked', 'Frisked'], loc='upper right')  
plt.show()

# %%
# %%

# Visualize frisks by sex
sns.catplot(x='sex', hue='frisked', data=df_clean, kind='count', palette='coolwarm', edgecolor='0.6')
plt.title('Frisks by Sex'); plt.grid()
plt.subplots_adjust(left=0.0, bottom=0.0, right=1, top=0.6, wspace=0.01, hspace=0.2)

# %%
# %%

# Visualize frisks by city
sns.catplot(x='city', hue='frisked', data=df_clean, kind='count', palette='coolwarm', edgecolor='0.6')
plt.title('Frisks by city'); plt.grid()
plt.subplots_adjust(left=0.0, bottom=0.0, right=2, top=0.8, wspace=0.01, hspace=0.2)

# %%
#%%

# Scatter plot of age, height, and weight
sns.pairplot(df_clean[['age', 'height', 'weight']])
plt.show()

# Correlation matrix
corr_matrix = df_clean[['age', 'height', 'weight']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# Cross-tabulation between reasons for SQF and type of force used
cross_tab = pd.crosstab(df_clean['crimsusp'], df_clean['forceuse'])
print(cross_tab)

# Group-wise averages of numerical attributes by reasons for SQF and type of force used
grouped_avg = df_clean.groupby(['crimsusp', 'forceuse'])[['age', 'height', 'weight']].mean()
print(grouped_avg)
# Out:
# forceuse                        DEFENSE OF OTHER  DEFENSE OF SELF  OTHER  \
# crimsusp
#   CPW                                          0                0      0
#   FEL                                          0                1      0
#  ASSAULT                                       1                0      0
#  CPM/ GLA                                      0                0      1
#  CPW                                           0                2      0
#  CPW/ CSCS                                     0                0      0
#  ENDANGER MISD PSA#1278                        0                0      1
#  FEL                                           0                0      2
#  FELONY                                        0                0      0
#  MISD                                          0                2      1
#  MISDEMEANOR                                   0                1      0
#  PETIT LARCENY                                 0                0      0
#  PETIT LARCENY/CPSP                            0                0      1
# ,ISD                                           0                0      0
# 10-10 MAN W/GUN (CPW)                          0                0      0
# 10-30                                          0                0      0
# 10-31 BURGLARY                                 0                1      0
# 10-34/SHOOTING                                 0                0      0
# 1192 VTL                                       0                0      1
# 1192.1 VTL                                     0                0      1
# 120                                            0                0      3
# 120.00                                         0                0      1
# 12000                                          0                0      1
# 12693                                          0                0      0
# 140.15                                         0                1      1
# 160.15                                         0                0      0
# 160.15 ROBBERY                                 0                1      0
# 220.16 / FEL                                   0                0      0
# 220.39                                         0                0      1
# 220.39  FEL                                    0                1      0
# 220.39 (1)  PL                                 0                0      0
# 220.39, 265.01                                 0                0      0
# 221.1                                          0                2      1
# 221.10                                         0                0      4
# 221.10 140.15                                  0                0      1
# 221.15                                         0                1      0
# 221.35                                         0                1      0
# 221.40                                         0                0      0
# 265.01                                         0                2      0
# 265.03                                         0                0      0
# 265.03 / CPCS                                  0                0      0
# 275.40                                         0                1      0
# A                                              0                1      0
# ABDUCTOR FROM 32 PCT                           0                1      0
# AGG HAR                                        0                0      1
# AGG HARAS                                      0                1      0
# AGG HARASSMENT                                 0                0      0
# AGG PANHANDLING                                0                1      0
# AGG.HARRASSMENT                                0                0      0
# AGGRAVATED HARASSMENT                          0                1      0
# AGGRAVATED HARRASSMENT                         0                0      1
# AGGRESIVE PANHANDLING                          0                0      5
# AGGRESSIVE PANHANDLE                           0                0      0
# AGRESSIVE PANHANDLE                            0                0      0
# AGREVATED HARASSMENT                           0                0      1
# AHGGRESIVE PANHANDLING                         0                0      1
# ARSON                                          0                2      0
# ASAAULT                                        0                0      0
# ASAAULT 2                                      0                0      0
# ASAULT                                         0                0      0
# ASLT 3                                         0                0      0
# ASS                                            2               11      8
# ASS 2/CPW                                      0                1      0
# ASS 3                                          0                3      0
# ASS2                                           0                2      0
# ASS3                                           0                3      0
# ASS3/CPW                                       1                0      0
# ASSALULT                                       0                0      1
# ASSALUT                                        0                0      1
# ASSAUALT                                       0                0      1
# ROBBERY 2                      DEFENSE OF SELF      230.000000
#                                SUSPECTED FLIGHT     130.000000
# ROBBERY AND CPW                SUSPECTED FLIGHT     221.000000
# ROBBERY CPW                    DEFENSE OF SELF      145.000000
# ROBBERY FEL                    SUSPECTED FLIGHT     170.000000
# ROBBERY FEL  PSA#1219          DEFENSE OF SELF      145.000000
# ROBBERY FEL PSA#1224           OTHER                140.000000
# ROBBERY FEL PSA#1225           OTHER                170.000000
# ROBBERY FEL PSA#781            SUSPECTED FLIGHT     160.000000
# ROBBERY MISD                   DEFENSE OF SELF      200.000000
# ROBBERY MISD PSA#493           DEFENSE OF SELF      175.000000
# ROBBERY OF LIVERY CAB          SUSPECTED FLIGHT     140.000000
# ROBBERY OF LIVERY CAR          SUSPECTED FLIGHT     180.000000
# ROBBERY PATTERN                OTHER                180.000000
#                                SUSPECTED FLIGHT     140.000000
# ROBBERY PATTERN / BURGLARY     DEFENSE OF SELF      150.000000
# ROBBERY PATTERN 112            DEFENSE OF SELF      180.000000
#                                SUSPECTED WEAPON     140.000000
# ROBBERY PL 160.10              OTHER                150.000000
# ROBBERY W/ WEAPON              OTHER                165.000000
# ROBBERY(STRONG ARM)            OTHER                170.000000
# ROBBERY, CPW                   SUSPECTED WEAPON     100.000000
# ROBBERY, CPW, LOOKOUT          SUSPECTED WEAPON     190.000000
# ROBBERY- TRESSPASS             DEFENSE OF SELF      200.000000
# ROBBERY-CPW                    SUSPECTED WEAPON     180.000000
# ROBBERY-FELONY                 DEFENSE OF SELF      240.000000
# ROBBERY/ ASSAULT               SUSPECTED FLIGHT     135.000000
# ROBBERY/ BURGLARY / PATTERN 25 DEFENSE OF SELF      180.000000
# ROBBERY/ CPW                   DEFENSE OF SELF      180.000000
#                                SUSPECTED FLIGHT     210.000000
# ROBBERY/ FEL                   SUSPECTED FLIGHT     165.000000
# ROBBERY/ASSAULT                DEFENSE OF SELF      205.000000
#                                OVERCOME RESISTANCE  180.000000
# ROBBERY/BURGLARY               DEFENSE OF SELF      160.000000
#                                SUSPECTED FLIGHT     140.000000
# ROBBERY/CPW                    DEFENSE OF OTHER     165.000000
#                                DEFENSE OF SELF      178.333333
#                                OTHER                149.000000
#                                OVERCOME RESISTANCE  160.000000
#                                SUSPECTED FLIGHT     168.750000
#                                SUSPECTED WEAPON     161.666667
# ROBBERY/CPW/FELONY             SUSPECTED FLIGHT     160.000000
# ROBBERY/FEL                    DEFENSE OF SELF      150.000000
# ROBBERY/GL                     DEFENSE OF SELF      160.000000
# ROBBERY/GLA                    SUSPECTED FLIGHT     140.000000
# ROBBERY1                       SUSPECTED FLIGHT     170.000000
# ROBBERYR                       DEFENSE OF SELF      165.000000
# ROBBEY                         OTHER                170.000000
# ROBBOERY                       DEFENSE OF SELF      220.000000
# ROBBRY                         DEFENSE OF SELF      150.000000
#                                OTHER                160.000000
#                                OVERCOME RESISTANCE  220.000000
# ROBEERY                        DEFENSE OF SELF      190.000000
# ROBERRY                        DEFENSE OF SELF      160.000000
#                                OVERCOME RESISTANCE  160.000000
#                                SUSPECTED FLIGHT     165.000000
# ROBERY                         DEFENSE OF SELF      193.333333
#                                OTHER                120.000000
#                                SUSPECTED FLIGHT     147.500000
# ROBERY/CRIM TRESPASS           DEFENSE OF SELF      150.000000
# ROOBERY                        DEFENSE OF SELF      200.000000
# SALE OF UNTAXED CIGARETTES     OTHER                230.000000
# SELLING DRUGS                  DEFENSE OF SELF      190.000000
#                                OTHER                140.000000
# SELLING SWIPE                  SUSPECTED FLIGHT     180.000000
# SELLING SWIPES                 OTHER                159.500000
#                                SUSPECTED FLIGHT     176.454545
# SELLING SWIPES 165.16          OTHER                150.000000
# SELLING SWIPES/LOITERING       SUSPECTED FLIGHT     145.000000
# SEX ABUSE                      DEFENSE OF SELF      155.000000
#                                OTHER                157.000000
#                                OVERCOME RESISTANCE  145.000000
#                                SUSPECTED FLIGHT     159.166667
#                                SUSPECTED WEAPON     180.000000
# SEX ABUSE / FOC. TOUCHING      DEFENSE OF SELF      150.000000
# SEX ASSAULT                    DEFENSE OF SELF      170.000000
# SEX MISCONDUCT                 SUSPECTED FLIGHT     150.000000
# SEXUAL ABUSE                   DEFENSE OF SELF      140.000000
#                                OVERCOME RESISTANCE  150.000000
#                                SUSPECTED FLIGHT     170.000000
# SEXUAL ASSAULT                 DEFENSE OF SELF      185.000000
#                                OTHER                150.000000
#                                SUSPECTED FLIGHT     180.000000
# SEXUAL ASSAULT / CPW           SUSPECTED FLIGHT     180.000000
# SEXUAL MISC                    DEFENSE OF SELF      165.000000
# SEXUAL MISCONDUCT              OTHER                180.000000
# SHOOTING                       OTHER                146.666667
#                                SUSPECTED FLIGHT     167.500000
# SHOOTING TOOK PL/ CRIM TRES    OTHER                145.000000
# SHOPLIFTING                    DEFENSE OF SELF      190.000000
# SILA/CPM                       OTHER                250.000000
# SODOMY                         OTHER                140.000000
#                                OVERCOME RESISTANCE  180.000000
# SOL PROS                       OTHER                170.000000
# SOLICITING PROSTITUTION        DEFENSE OF SELF      145.000000
# SPW                            DEFENSE OF SELF      155.000000
#                                SUSPECTED FLIGHT     165.000000
# STALKING                       DEFENSE OF SELF      210.000000
#                                OTHER                190.000000
#                                SUSPECTED FLIGHT     160.000000
# STALKING/AGGRAVATED HARASSMENT OTHER                150.000000
# STRANGULATION                  DEFENSE OF SELF      130.000000
#                                OTHER                140.000000
#                                SUSPECTED FLIGHT     170.000000
# SUSPECT OF SHOOTING/CPW        DEFENSE OF SELF      160.000000
# SUSPECTED ASSAULT              DEFENSE OF SELF      102.000000
# SUSPECTED GLA                  DEFENSE OF SELF      170.000000
# SUSPED OF CPW/RADIO RUN        DEFENSE OF SELF      162.000000
# SWIPE                          SUSPECTED FLIGHT     190.000000
# SWIPER                         DEFENSE OF OTHER     180.000000
#                                SUSPECTED FLIGHT     162.615385
# SWIPES                         OTHER                187.000000
#                                OVERCOME RESISTANCE  250.000000
#                                SUSPECTED FLIGHT     145.000000
# SWIPING                        DEFENSE OF SELF      170.000000
#                                OTHER                185.000000
#                                OVERCOME RESISTANCE  163.750000
#                                SUSPECTED FLIGHT     168.684211
#                                SUSPECTED WEAPON     140.000000
# SWIPING 165.16                 SUSPECTED FLIGHT     140.000000
# SWIPING/LOITERING              SUSPECTED FLIGHT     170.000000
# SWIPPER                        SUSPECTED FLIGHT     172.500000
# SWIPPING                       DEFENSE OF SELF      215.000000
#                                SUSPECTED FLIGHT     130.000000
# TERROISM                       OVERCOME RESISTANCE  145.000000
# TERRORISM                      SUSPECTED FLIGHT     160.000000
#                                SUSPECTED WEAPON     200.000000
# TERRORISM THREAT               DEFENSE OF SELF      150.000000
# THAFT OF SERVICE               OTHER                115.000000
# THEFT OF SER.                  OVERCOME RESISTANCE  170.000000
# THEFT OF SERVICE               DEFENSE OF SELF      177.166667
#                                OTHER                160.000000
#                                OVERCOME RESISTANCE  170.000000
#                                SUSPECTED FLIGHT     158.533333
# THEFT OF SERVICES              DEFENSE OF SELF      166.666667
#                                OTHER                145.000000
#                                OVERCOME RESISTANCE  150.000000
#                                SUSPECTED FLIGHT     167.500000
# THEFT OF SEVICES               OTHER                160.000000
# TICKET SPECULATION / CPW       DEFENSE OF SELF      150.000000
# TMC                            OTHER                150.000000
# TOS                            DEFENSE OF OTHER     165.000000
#                                DEFENSE OF SELF      181.428571
#                                OTHER                176.000000
#                                OVERCOME RESISTANCE  145.000000
#                                SUSPECTED FLIGHT     158.095238
#                                SUSPECTED WEAPON     185.000000
# TOS/CPW (FIREARM)              OTHER                190.000000
# TRADE MARK COUNTERFITING       SUSPECTED WEAPON     160.000000
# TRADEMARK                      OTHER                170.000000
# TRADEMARK COUNTEFEIT           SUSPECTED FLIGHT     150.000000
# TRADEMARK COUNTERFEIT          DEFENSE OF SELF      210.000000
#                                OVERCOME RESISTANCE  180.000000
#                                SUSPECTED FLIGHT     150.000000
# TRADEMARK COUNTERFEITING       DEFENSE OF SELF      175.000000
#                                OTHER                147.500000
#                                SUSPECTED FLIGHT     120.000000
# TRADEMARK COUNTERFIT           DEFENSE OF SELF      140.000000
# TREPASS                        SUSPECTED FLIGHT     198.000000
# TRES                           DEFENSE OF SELF      130.000000
#                                OTHER                142.500000
# TRESPAS                        DEFENSE OF SELF      170.000000
#                                SUSPECTED WEAPON     150.000000
# TRESPASS                       DEFENSE OF SELF      157.380952
#                                OTHER                158.125000
#                                OVERCOME RESISTANCE  155.000000
#                                SUSPECTED FLIGHT     159.583333
# TRESPASS / ASSAULT             OTHER                170.000000
# TRESPASS / CPM                 DEFENSE OF SELF      157.500000
#                                SUSPECTED FLIGHT     280.000000
# TRESPASS/CPW                   DEFENSE OF SELF      150.000000
# TRESPASS/ROBBERY               OTHER                120.000000
# TRESPASSING                    DEFENSE OF SELF      155.000000
#                                OVERCOME RESISTANCE  150.000000
#                                SUSPECTED FLIGHT     160.000000
#                                SUSPECTED WEAPON     130.000000
# TRESS PASS                     SUSPECTED FLIGHT     170.000000
# TRESSPASS                      DEFENSE OF SELF      158.333333
# TRPS                           OTHER                180.000000
# UNAUTH SALE TRANS SERVICES 165 SUSPECTED FLIGHT     176.000000
# UNAUTH USE AUTO                DEFENSE OF SELF      160.000000
# UNAUTH USE MV                  SUSPECTED FLIGHT     125.000000
# UNAUTHORIZED SALE OF FARE CARD DEFENSE OF SELF      191.200000
#                                OTHER                156.666667
#                                SUSPECTED WEAPON     170.000000
# UNAUTHORIZED SALE OF FARE MEDI SUSPECTED FLIGHT     175.000000
# UNAUTHORIZED SURVEILLANCE      OTHER                180.000000
# UNAUTHORIZED USE OF VEHICLE    SUSPECTED FLIGHT     200.000000
# UNLAW FLEEING A POLICE OFFICER OTHER                150.000000
# UNLAW SALE FARE MEDIA          DEFENSE OF SELF      150.000000
# UNLAWFUL ASSEMBLY              DEFENSE OF SELF      145.000000
#                                OTHER                125.000000
#                                SUSPECTED FLIGHT     193.750000
# UNLAWFUL DEALING W/ MINOR      OTHER                202.500000
# UNLAWFUL FIREWORKS             DEFENSE OF SELF      300.000000
# UNLAWFUL IMPRISONMENT          SUSPECTED FLIGHT     200.000000
# UNLAWFUL SALE OF FARE MEDIA    DEFENSE OF SELF      145.000000
# UNLAWFUL SURV                  OTHER                130.000000
# UNLAWFUL SURVEILANCE           OTHER                150.000000
# UNLAWFUL SURVEILLANCE          DEFENSE OF OTHER     170.000000
#                                OTHER                188.333333
#                                OVERCOME RESISTANCE  150.000000
# UNLAWFULL ASSEMBLY             OTHER                175.500000
# UNLWFL SURV                    OTHER                150.000000
# UNSTAMPED CIGARETTES           OTHER                160.000000
# UPM                            DEFENSE OF SELF      170.000000
# UPM/ POS OF WEAPON             OTHER                160.000000
# USFC                           DEFENSE OF SELF      170.000000
#                                OTHER                185.000000
# USFM                           DEFENSE OF SELF      161.250000
# USFM-UNLAWFUL SALE FARE MEDIA  DEFENSE OF SELF      250.000000
# UUV                            SUSPECTED FLIGHT     180.000000
#                                SUSPECTED WEAPON     230.000000
# V                              OTHER                100.000000
# V/O/P                          OTHER                180.000000
# VEH ASSAULT/DWI                SUSPECTED FLIGHT     200.000000
# VEL                            DEFENSE OF SELF      150.000000
# VIOL OF ORDER OF PROTECTION    OTHER                200.000000
# VIOLATE OOP                    OTHER                165.000000
# VIOLATION                      DEFENSE OF SELF      165.000000
# VOOP CRIM CONTEMPT             OTHER                200.000000
# VOP                            SUSPECTED FLIGHT     180.000000
# VTL 511                        OTHER                270.000000

# %% [markdown]
# Top Row, Left to Right:
#
# Histogram of Age: This plot shows the distribution of age. It appears that the data is somewhat normally distributed with a peak around 50 years.
# Scatter Plot of Age vs. Height: This plot shows a cloud of points that suggests there is little to no clear correlation between age and height.
# Scatter Plot of Age vs. Weight: Similar to the age vs. height plot, this scatter plot shows a distribution of points with no apparent correlation between age and weight.
# Middle Row, Left to Right:
#
# Scatter Plot of Height vs. Age: This is the same as the top row middle plot but oriented differently, showing height on the y-axis and age on the x-axis.
# Histogram of Height: This histogram shows the distribution of height, which appears to be normally distributed with a peak around 170 cm.
# Scatter Plot of Height vs. Weight: This plot suggests a positive correlation between height and weight, as the points trend upwards from left to right.
# Bottom Row, Left to Right:
#
# Scatter Plot of Weight vs. Age: This plot mirrors the top row right plot, showing weight on the y-axis and age on the x-axis.
# Scatter Plot of Weight vs. Height: This is the same as the middle row right plot, showing weight on the y-axis and height on the x-axis.
# Histogram of Weight: The distribution of weight is shown here, with a peak around 200 pounds and a right-skewed distribution.
#
# Correlation Matrix
#
# Here are the specific correlation coefficients:
#
# The correlation between age and itself is 1.00, which is always the case for any variable with itself.
# The correlation between age and height is 0.07, suggesting a very weak positive relationship.
# The correlation between age and weight is 0.24, indicating a weak positive correlation.
# The correlation between height and age is 0.07, which is the same as age to height due to the symmetric nature of correlation matrices.
# The correlation between height and itself is 1.00.
# The correlation between height and weight is 0.45, suggesting a moderate positive correlation.
# The correlation between weight and age is 0.24.
# The correlation between weight and height is 0.45.
# The correlation between weight and itself is 1.00.

# %%
#%%

# Group-wise averages of numerical attributes by crimsusp, forceuse, and type of force used
grouped_avg_with_force = df_clean.groupby(['crimsusp', 'forceuse', 'pf_hands', 'pf_wall', 'pf_grnd', 'pf_drwep', 'pf_ptwep', 'pf_baton', 'pf_hcuff', 'pf_pepsp', 'pf_other'])[['age', 'height', 'weight']].mean()
print(grouped_avg_with_force)
# Out:
#                                                                                                                      age  \
# crimsusp           forceuse         pf_hands pf_wall pf_grnd pf_drwep pf_ptwep pf_baton pf_hcuff pf_pepsp pf_other
#   CPW              SUSPECTED FLIGHT Y        N       N       N        N        N        N        N        N         36.0
#   FEL              DEFENSE OF SELF  N        N       N       N        N        N        Y        N        N         30.0
#  ASSAULT           DEFENSE OF OTHER N        Y       N       N        N        N        N        N        N         44.0
#  CPM/ GLA          OTHER            N        N       N       N        N        N        Y        N        N         20.0
#  CPW               DEFENSE OF SELF  Y        N       N       N        N        N        N        N        N         26.0
# ...                                                                                                                  ...
# VIOLATE OOP        OTHER            N        N       N       N        N        N        Y        N        N         23.0
# VIOLATION          DEFENSE OF SELF  N        N       N       N        N        N        Y        N        N         38.0
# VOOP CRIM CONTEMPT OTHER            Y        N       N       N        N        N        Y        N        N         46.0
# VOP                SUSPECTED FLIGHT N        N       N       N        N        N        Y        N        N         40.0
# VTL 511            OTHER            Y        Y       N       N        N        N        Y        N        N         39.0
#
#                                                                                                                     height  \
# crimsusp           forceuse         pf_hands pf_wall pf_grnd pf_drwep pf_ptwep pf_baton pf_hcuff pf_pepsp pf_other
#   CPW              SUSPECTED FLIGHT Y        N       N       N        N        N        N        N        N           68.0
#   FEL              DEFENSE OF SELF  N        N       N       N        N        N        Y        N        N           71.0
#  ASSAULT           DEFENSE OF OTHER N        Y       N       N        N        N        N        N        N           68.0
#  CPM/ GLA          OTHER            N        N       N       N        N        N        Y        N        N           71.0
#  CPW               DEFENSE OF SELF  Y        N       N       N        N        N        N        N        N           67.5
# ...                                                                                                                    ...
# VIOLATE OOP        OTHER            N        N       N       N        N        N        Y        N        N           64.0
# VIOLATION          DEFENSE OF SELF  N        N       N       N        N        N        Y        N        N           73.0
# VOOP CRIM CONTEMPT OTHER            Y        N       N       N        N        N        Y        N        N           74.0
# VOP                SUSPECTED FLIGHT N        N       N       N        N        N        Y        N        N           66.0
# VTL 511            OTHER            Y        Y       N       N        N        N        Y        N        N           71.0
#
#                                                                                                                     weight
# crimsusp           forceuse         pf_hands pf_wall pf_grnd pf_drwep pf_ptwep pf_baton pf_hcuff pf_pepsp pf_other
#   CPW              SUSPECTED FLIGHT Y        N       N       N        N        N        N        N        N          150.0
#   FEL              DEFENSE OF SELF  N        N       N       N        N        N        Y        N        N          180.0
#  ASSAULT           DEFENSE OF OTHER N        Y       N       N        N        N        N        N        N          160.0
#  CPM/ GLA          OTHER            N        N       N       N        N        N        Y        N        N          180.0
#  CPW               DEFENSE OF SELF  Y        N       N       N        N        N        N        N        N          175.0
# ...                                                                                                                    ...
# VIOLATE OOP        OTHER            N        N       N       N        N        N        Y        N        N          165.0
# VIOLATION          DEFENSE OF SELF  N        N       N       N        N        N        Y        N        N          165.0
# VOOP CRIM CONTEMPT OTHER            Y        N       N       N        N        N        Y        N        N          200.0
# VOP                SUSPECTED FLIGHT N        N       N       N        N        N        Y        N        N          180.0
# VTL 511            OTHER            Y        Y       N       N        N        N        Y        N        N          270.0
#
# [5071 rows x 3 columns]

# %%
# %%

#Creating a column to indicate whether someone was arrested, summonsed, or neither
arrest_condition = df_clean['arstmade'] == 'Y'
summons_condition = df_clean['sumissue'] == 'Y'
df_clean.loc[arrest_condition, 'outcome'] = 'Arrested'
df_clean.loc[summons_condition, 'outcome'] = 'Summons Issued'
sns.countplot(x='outcome', data=df_clean, palette='Set2')
plt.title('Outcomes of Police Encounters')
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-43-66e8835a0dce>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='outcome', data=df_clean, palette='Set2')

# %%
#%%

df_clean['trhsloc'].unique()
df_clean.dropna(subset=['trhsloc'], inplace=True)

# %%
# %%

# re-classifying trhsloc
Location_mapping = {
    'P': 'Neither',
    'H': 'Housing',
    'T': 'Transit'
}
df_clean['trhsloc'] = df_clean['trhsloc'].map(Location_mapping)

# %%
#%%

plt.figure(figsize=(10, 6))
sns.countplot(data=df_clean, x='trhsloc', palette='coolwarm', edgecolor='0.6')
plt.title('Distribution of Locations')
plt.xlabel('Location')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-46-0fdcc0954aac>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_clean, x='trhsloc', palette='coolwarm', edgecolor='0.6')

# %%
#%%

df_clean['crimsusp'].value_counts()[0:5]
# Out:
# crimsusp
# FEL        104193
# MISD        80633
# FELONY      68896
# CPW         55134
# ROBBERY     48286
# Name: count, dtype: int64

# %%
#%%

df_clean.head()
# Out:
#    year  pct  ser_num  datestop  timestop recstat inout  trhsloc  perobs  \
# 0  2012   40       17   1012012       115       1     O  Neither       2
# 1  2012   23      691   1012012       310       1     I  Neither       2
# 2  2012   81     3714   1012012      2000       1     O  Neither       1
# 3  2012   81      633   1022012      1245       1     O  Neither       3
# 4  2012   66       36   1042012      2220       A     O  Neither       2
#
#   crimsusp perstop typeofid explnstp othpers arstmade arstoffn sumissue  \
# 0  ROBBERY       5        V        Y       N        N                 N
# 1        M       5        P        Y       N        N                 N
# 2  ROBBERY       5        V        Y       N        N                 N
# 3  ROBBERY       5        P        Y       N        N                 N
# 4   FELONY      10        V        Y       Y        N                 N
#
#   sumoffen  compyear  comppct offunif officrid frisked searched contrabn  \
# 0                  0        0       Y                Y        N        N
# 1                  0        0       Y                N        N        N
# 2                  0        0       Y                N        N        N
# 3                  0        0       Y                N        N        N
# 4                  0        0       N                N        N        N
#
#   adtlrept pistol riflshot asltweap knifcuti machgun othrweap pf_hands  \
# 0        N      N        N        N        N       N        N        N
# 1        N      N        N        N        N       N        N        N
# 2        N      N        N        N        N       N        N        N
# 3        N      N        N        N        N       N        N        N
# 4        N      N        N        N        N       N        N        N
#
#   pf_wall pf_grnd pf_drwep pf_ptwep pf_baton pf_hcuff pf_pepsp pf_other radio  \
# 0       N       N        N        N        N        N        N        N     N
# 1       N       N        N        N        N        N        N        N     Y
# 2       N       N        N        N        N        N        N        N     N
# 3       N       N        N        N        N        N        N        N     Y
# 4       N       N        N        N        N        N        N        N     N
#
#   ac_rept ac_inves rf_vcrim rf_othsw ac_proxm rf_attir cs_objcs cs_descr  \
# 0       N        Y        Y        N        N        N        N        N
# 1       N        N        N        N        N        N        N        N
# 2       N        Y        N        N        N        N        N        Y
# 3       N        N        N        N        N        N        N        Y
# 4       N        Y        N        N        N        N        N        Y
#
#   cs_casng cs_lkout rf_vcact cs_cloth cs_drgtr ac_evasv ac_assoc cs_furtv  \
# 0        Y        N        Y        N        N        Y        N        Y
# 1        N        N        N        N        N        Y        N        N
# 2        N        N        N        N        N        N        Y        N
# 3        N        N        N        N        N        N        N        N
# 4        Y        N        N        N        N        N        N        N
#
#   rf_rfcmp ac_cgdir rf_verbl cs_vcrim cs_bulge cs_other ac_incid ac_time  \
# 0        Y        Y        N        N        N        N        Y       Y
# 1        N        N        N        N        N        Y        Y       Y
# 2        N        Y        N        N        N        N        Y       Y
# 3        N        N        N        N        N        N        N       Y
# 4        N        N        N        N        N        N        N       Y
#
#   rf_knowl ac_stsnd ac_other sb_hdobj sb_outln sb_admis sb_other repcmd  \
# 0        N        N        N        N        N        N        N     40
# 1        N        Y        N        N        N        N        N     23
# 2        N        N        N        N        N        N        N     81
# 3        N        N        N        N        N        N        N     81
# 4        N        N        N        N        N        N        N     72
#
#    revcmd rf_furt rf_bulg offverb offshld forceuse   sex            race  \
# 0      40       Y       N                      NaN  Male           BLACK
# 1      23       N       N                      NaN  Male  WHITE-HISPANIC
# 2      81       N       N                      NaN  Male           BLACK
# 3      81       N       N                      NaN  Male           BLACK
# 4      72       N       N               S      NaN  Male  WHITE-HISPANIC
#
#         dob  age  weight haircolr eyecolor   build othfeatr addrtyp rescode  \
# 0  12311900   20     155    BLACK    BROWN    THIN                R
# 1  12311900   18     175    BLACK    BROWN  MEDIUM                R
# 2  12311900   19     180    BLACK    BROWN  MEDIUM                R
# 3  12311900   37     210    BLACK    BROWN   HEAVY                R
# 4   5211990   21     170    BLACK    BROWN  MEDIUM                R
#
#   premtype  premname addrnum           stname                stinter  \
# 0           SIDEWALK                                  CYPRESS AVENUE
# 1                        310  EAST 110 STREET               1 AVENUE
# 2                  T                                    LEWIS AVENUE
# 3                 ST    1839    FULTON STREET           RALPH AVENUE
# 4             STREET                           FORT HAMILTON PARKWAY
#
#            crossst aptnum       city state zip addrpct sector beat post  \
# 0  EAST 139 STREET             BRONX                40      C    *
# 1         2 AVENUE         MANHATTAN                23      D        12
# 2    GREENE AVENUE          BROOKLYN                81      C    3
# 3   PATCHEN AVENUE          BROOKLYN                81      J    *
# 4        39 STREET          BROOKLYN                66      J
#
#     xcoord   ycoord dettypcm linecm detailcm  height age_category outcome
# 0  1008031   233036       CM      1       85      69  young_adult     nan
# 1  1000852   228179       CM      1        9      67  young_adult     nan
# 2  1001869   190702       CM      1       85      69  young_adult     nan
# 3  1005306   186668       CM      1       85      65  middle_aged     nan
# 4   986887   173599       CM      1       46      67  young_adult     nan

# %%
# %%

cross_tab = pd.crosstab(df_clean['cs_descr'], df_clean['forceuse'])

# Plotting cross-tabulation
plt.figure(figsize=(10, 6))
sns.heatmap(cross_tab, cmap='Blues', annot=True, fmt='d', cbar=True)
plt.title('Cross-tabulation of Reason for SQF vs. Type of Force Used')
plt.xlabel('Type of Force Used')
plt.ylabel('Reason for SQF')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
#%%

df_clean.head()
# Out:
#    year  pct  ser_num  datestop  timestop recstat inout  trhsloc  perobs  \
# 0  2012   40       17   1012012       115       1     O  Neither       2
# 1  2012   23      691   1012012       310       1     I  Neither       2
# 2  2012   81     3714   1012012      2000       1     O  Neither       1
# 3  2012   81      633   1022012      1245       1     O  Neither       3
# 4  2012   66       36   1042012      2220       A     O  Neither       2
#
#   crimsusp perstop typeofid explnstp othpers arstmade arstoffn sumissue  \
# 0  ROBBERY       5        V        Y       N        N                 N
# 1        M       5        P        Y       N        N                 N
# 2  ROBBERY       5        V        Y       N        N                 N
# 3  ROBBERY       5        P        Y       N        N                 N
# 4   FELONY      10        V        Y       Y        N                 N
#
#   sumoffen  compyear  comppct offunif officrid frisked searched contrabn  \
# 0                  0        0       Y                Y        N        N
# 1                  0        0       Y                N        N        N
# 2                  0        0       Y                N        N        N
# 3                  0        0       Y                N        N        N
# 4                  0        0       N                N        N        N
#
#   adtlrept pistol riflshot asltweap knifcuti machgun othrweap pf_hands  \
# 0        N      N        N        N        N       N        N        N
# 1        N      N        N        N        N       N        N        N
# 2        N      N        N        N        N       N        N        N
# 3        N      N        N        N        N       N        N        N
# 4        N      N        N        N        N       N        N        N
#
#   pf_wall pf_grnd pf_drwep pf_ptwep pf_baton pf_hcuff pf_pepsp pf_other radio  \
# 0       N       N        N        N        N        N        N        N     N
# 1       N       N        N        N        N        N        N        N     Y
# 2       N       N        N        N        N        N        N        N     N
# 3       N       N        N        N        N        N        N        N     Y
# 4       N       N        N        N        N        N        N        N     N
#
#   ac_rept ac_inves rf_vcrim rf_othsw ac_proxm rf_attir cs_objcs cs_descr  \
# 0       N        Y        Y        N        N        N        N        N
# 1       N        N        N        N        N        N        N        N
# 2       N        Y        N        N        N        N        N        Y
# 3       N        N        N        N        N        N        N        Y
# 4       N        Y        N        N        N        N        N        Y
#
#   cs_casng cs_lkout rf_vcact cs_cloth cs_drgtr ac_evasv ac_assoc cs_furtv  \
# 0        Y        N        Y        N        N        Y        N        Y
# 1        N        N        N        N        N        Y        N        N
# 2        N        N        N        N        N        N        Y        N
# 3        N        N        N        N        N        N        N        N
# 4        Y        N        N        N        N        N        N        N
#
#   rf_rfcmp ac_cgdir rf_verbl cs_vcrim cs_bulge cs_other ac_incid ac_time  \
# 0        Y        Y        N        N        N        N        Y       Y
# 1        N        N        N        N        N        Y        Y       Y
# 2        N        Y        N        N        N        N        Y       Y
# 3        N        N        N        N        N        N        N       Y
# 4        N        N        N        N        N        N        N       Y
#
#   rf_knowl ac_stsnd ac_other sb_hdobj sb_outln sb_admis sb_other repcmd  \
# 0        N        N        N        N        N        N        N     40
# 1        N        Y        N        N        N        N        N     23
# 2        N        N        N        N        N        N        N     81
# 3        N        N        N        N        N        N        N     81
# 4        N        N        N        N        N        N        N     72
#
#    revcmd rf_furt rf_bulg offverb offshld forceuse   sex            race  \
# 0      40       Y       N                      NaN  Male           BLACK
# 1      23       N       N                      NaN  Male  WHITE-HISPANIC
# 2      81       N       N                      NaN  Male           BLACK
# 3      81       N       N                      NaN  Male           BLACK
# 4      72       N       N               S      NaN  Male  WHITE-HISPANIC
#
#         dob  age  weight haircolr eyecolor   build othfeatr addrtyp rescode  \
# 0  12311900   20     155    BLACK    BROWN    THIN                R
# 1  12311900   18     175    BLACK    BROWN  MEDIUM                R
# 2  12311900   19     180    BLACK    BROWN  MEDIUM                R
# 3  12311900   37     210    BLACK    BROWN   HEAVY                R
# 4   5211990   21     170    BLACK    BROWN  MEDIUM                R
#
#   premtype  premname addrnum           stname                stinter  \
# 0           SIDEWALK                                  CYPRESS AVENUE
# 1                        310  EAST 110 STREET               1 AVENUE
# 2                  T                                    LEWIS AVENUE
# 3                 ST    1839    FULTON STREET           RALPH AVENUE
# 4             STREET                           FORT HAMILTON PARKWAY
#
#            crossst aptnum       city state zip addrpct sector beat post  \
# 0  EAST 139 STREET             BRONX                40      C    *
# 1         2 AVENUE         MANHATTAN                23      D        12
# 2    GREENE AVENUE          BROOKLYN                81      C    3
# 3   PATCHEN AVENUE          BROOKLYN                81      J    *
# 4        39 STREET          BROOKLYN                66      J
#
#     xcoord   ycoord dettypcm linecm detailcm  height age_category outcome
# 0  1008031   233036       CM      1       85      69  young_adult     nan
# 1  1000852   228179       CM      1        9      67  young_adult     nan
# 2  1001869   190702       CM      1       85      69  young_adult     nan
# 3  1005306   186668       CM      1       85      65  middle_aged     nan
# 4   986887   173599       CM      1       46      67  young_adult     nan

# %%
#%%

df_clean = df_clean.drop(['outcome', 'age_category'], axis=1)

# %%
#%%

#Export Cleaned data to csv
df_clean.to_csv('df_clean.csv', index=False)

# %%
#%%

# Define the columns containing 'Y' and 'N' values
columns_to_convert = [
    'othpers', 'arstmade', 'sumissue', 'offunif', 'frisked', 'searched', 'contrabn', 'adtlrept', 
    'pistol', 'riflshot', 'asltweap', 'knifcuti', 'machgun', 'othrweap', 'pf_hands', 'pf_wall', 
    'pf_grnd', 'pf_drwep', 'pf_ptwep', 'pf_baton', 'pf_hcuff', 'pf_pepsp', 'pf_other', 'radio', 
    'ac_rept', 'ac_inves', 'rf_vcrim', 'rf_othsw', 'ac_proxm', 'rf_attir', 'cs_objcs', 'cs_descr', 
    'cs_casng', 'cs_lkout', 'rf_vcact', 'cs_cloth', 'cs_drgtr', 'ac_evasv', 'ac_assoc', 'cs_furtv', 
    'rf_rfcmp', 'ac_cgdir', 'rf_verbl', 'cs_vcrim', 'cs_bulge', 'cs_other', 'ac_incid', 'ac_time', 
    'rf_knowl', 'ac_stsnd', 'ac_other', 'sb_hdobj', 'sb_outln', 'sb_admis', 'sb_other', 'rf_furt', 
    'rf_bulg'
]

# Convert 'Y' and 'N' to binary (1 and 0) for the specified columns and change the data type to int
df_clean[columns_to_convert] = df_clean[columns_to_convert].replace({'Y': 1, 'N': 0}).astype(int)

#Export cleaned binary converted data to csv
df_clean.to_csv('df_bin.csv', index=False)

# Now 'Y' and 'N' values in specified columns are replaced with 1 and 0, respectively, and data type is changed to int

# %%
#%%

numerical_columns = df_clean.select_dtypes(exclude=['object'])
numerical_description = numerical_columns.describe(include='all')
print("Numerical Columns Description:\n", numerical_description)
numerical_description.columns.shape
# Out:
# Numerical Columns Description:
#             year            pct        ser_num      datestop       timestop  \
# count  527415.0  527415.000000  527415.000000  5.274150e+05  527415.000000
# mean     2012.0      66.631952    4987.816856  5.564298e+06    1415.154341
# std         0.0      32.310859    4363.631385  3.412679e+06     737.171272
# min      2012.0       1.000000       1.000000  1.012012e+06       0.000000
# 25%      2012.0      41.000000    1794.000000  2.292012e+06    1000.000000
# 50%      2012.0      70.000000    3800.000000  5.052012e+06    1615.000000
# 75%      2012.0      94.000000    6991.000000  8.252012e+06    2030.000000
# max      2012.0     123.000000   24652.000000  1.231201e+07    2359.000000
#
#               perobs        othpers       arstmade       sumissue  compyear  \
# count  527415.000000  527415.000000  527415.000000  527415.000000  527415.0
# mean        2.408523       0.190744       0.060694       0.051546       0.0
# std         3.526319       0.392888       0.238769       0.221108       0.0
# min         0.000000       0.000000       0.000000       0.000000       0.0
# 25%         1.000000       0.000000       0.000000       0.000000       0.0
# 50%         1.000000       0.000000       0.000000       0.000000       0.0
# 75%         2.000000       0.000000       0.000000       0.000000       0.0
# max        60.000000       1.000000       1.000000       1.000000       0.0
#
#         comppct        offunif        frisked       searched       contrabn  \
# count  527415.0  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.0       0.753010       0.557891       0.083062       0.017279
# std         0.0       0.431261       0.496638       0.275976       0.130308
# min         0.0       0.000000       0.000000       0.000000       0.000000
# 25%         0.0       1.000000       0.000000       0.000000       0.000000
# 50%         0.0       1.000000       1.000000       0.000000       0.000000
# 75%         0.0       1.000000       1.000000       0.000000       0.000000
# max         0.0       1.000000       1.000000       1.000000       1.000000
#
#        adtlrept         pistol       riflshot       asltweap       knifcuti  \
# count  527415.0  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.0       0.001253       0.000025       0.000097       0.008837
# std         0.0       0.035380       0.004965       0.009833       0.093591
# min         0.0       0.000000       0.000000       0.000000       0.000000
# 25%         0.0       0.000000       0.000000       0.000000       0.000000
# 50%         0.0       0.000000       0.000000       0.000000       0.000000
# 75%         0.0       0.000000       0.000000       0.000000       0.000000
# max         0.0       1.000000       1.000000       1.000000       1.000000
#
#              machgun       othrweap       pf_hands        pf_wall  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.000006       0.002484       0.131481       0.023706
# std         0.002385       0.049776       0.337926       0.152132
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#              pf_grnd       pf_drwep       pf_ptwep       pf_baton  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.003432       0.002442       0.002325       0.000106
# std         0.058481       0.049357       0.048158       0.010304
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#             pf_hcuff       pf_pepsp       pf_other          radio  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.036139       0.000108       0.006509       0.241711
# std         0.186635       0.010395       0.080416       0.428120
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#              ac_rept       ac_inves       rf_vcrim       rf_othsw  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.125685       0.139920       0.129831       0.033389
# std         0.331494       0.346905       0.336118       0.179651
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#             ac_proxm       rf_attir       cs_objcs       cs_descr  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.226156       0.073946       0.025278       0.164952
# std         0.418342       0.261683       0.156968       0.371137
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#             cs_casng       cs_lkout       rf_vcact       cs_cloth  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.356342       0.189075       0.082144       0.046991
# std         0.478918       0.391569       0.274584       0.211621
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         1.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#             cs_drgtr       ac_evasv       ac_assoc       cs_furtv  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.073011       0.189839       0.045469       0.515905
# std         0.260155       0.392174       0.208330       0.499747
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       1.000000
# 75%         0.000000       0.000000       0.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#             rf_rfcmp       ac_cgdir       rf_verbl       cs_vcrim  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.079262       0.238309       0.006301       0.110897
# std         0.270148       0.426050       0.079126       0.314005
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#             cs_bulge       cs_other       ac_incid        ac_time  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.073043       0.156154       0.601067       0.439508
# std         0.260207       0.363002       0.489679       0.496328
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       1.000000       0.000000
# 75%         0.000000       0.000000       1.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#             rf_knowl       ac_stsnd       ac_other       sb_hdobj  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.018795       0.025576       0.034138       0.043577
# std         0.135802       0.157866       0.181584       0.204152
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#             sb_outln       sb_admis       sb_other         revcmd  \
# count  527415.000000  527415.000000  527415.000000  527415.000000
# mean        0.005218       0.002744       0.035537     237.839705
# std         0.072046       0.052307       0.185134     291.888035
# min         0.000000       0.000000       0.000000       1.000000
# 25%         0.000000       0.000000       0.000000      67.000000
# 50%         0.000000       0.000000       0.000000     107.000000
# 75%         0.000000       0.000000       0.000000     165.000000
# max         1.000000       1.000000       1.000000     879.000000
#
#              rf_furt        rf_bulg           dob            age  \
# count  527415.000000  527415.000000  5.274150e+05  527415.000000
# mean        0.393288       0.070112  8.945274e+06      28.130730
# std         0.488480       0.255336  3.839522e+06      11.863539
# min         0.000000       0.000000  1.011001e+06       5.000000
# 25%         0.000000       0.000000  6.051980e+06      19.000000
# 50%         0.000000       0.000000  1.031199e+07      24.000000
# 75%         1.000000       0.000000  1.231190e+07      34.000000
# max         1.000000       1.000000  1.231201e+07     100.000000
#
#               weight         height
# count  527415.000000  527415.000000
# mean      168.860747      68.600755
# std        29.114740       3.163585
# min        20.000000      36.000000
# 25%       150.000000      67.000000
# 50%       165.000000      69.000000
# 75%       180.000000      71.000000
# max       500.000000      95.000000
# (70,)

# %%
# %%

# Pickle Numerical Columns
numerical_columns.to_pickle("numerical_columns.pkl")
